# %% [markdown]
# # Affective Computing — Clasificador
# Autor conceptual: Copilot
#
# Este notebook permite:
# - Probar el clasificador afectivo
# - Visualizar estados detectados
# - Preparar dataset para fine-tuning

# %%
from affective.classifier import classify_text
classify_text("No entiendo este ejercicio, es muy difícil")

# %%
texts = [
    "No entiendo nada",
    "Creo que lo tengo",
    "Esto es aburrido",
    "Estoy frustrado"
]
[classify_text(t) for t in texts]
