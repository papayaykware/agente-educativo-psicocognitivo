# %% [markdown]
# # Deep Knowledge Tracing — Experimentos
# Autor conceptual: Copilot
#
# Este notebook permite:
# - Cargar interacciones del estudiante
# - Preparar secuencias para DKT
# - Entrenar un modelo simple
# - Visualizar probabilidades de dominio

# %%
from dkt.trainer import train_dkt
model, concept_map = train_dkt(epochs=3)

# %%
from dkt.predictor import predict_mastery
predict_mastery("student_001")
